# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

plt.style.use("ggplot")
rcParams['figure.figsize'] = (12,  6)

# %% [markdown]
# ### Loading the data

# %%
df = pd.read_csv(r'../data/CO2 Emissions_Canada.csv')

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
profile = ProfileReport(df, title="Pandas Profiling Report for CO2 Emission data", explorative=True)

# %%
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ### Visualizations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %% [markdown]
# #### Comparing CO2 emissions with make of the vehicle

# %%
make_vehicles = list(df.Make.value_counts().sort_values(ascending = False).keys())
make_vehicles
# Out:
# ['FORD',
#  'CHEVROLET',
#  'BMW',
#  'MERCEDES-BENZ',
#  'PORSCHE',
#  'TOYOTA',
#  'GMC',
#  'AUDI',
#  'NISSAN',
#  'JEEP',
#  'DODGE',
#  'KIA',
#  'HONDA',
#  'HYUNDAI',
#  'MINI',
#  'VOLKSWAGEN',
#  'MAZDA',
#  'LEXUS',
#  'JAGUAR',
#  'CADILLAC',
#  'SUBARU',
#  'VOLVO',
#  'INFINITI',
#  'BUICK',
#  'RAM',
#  'LINCOLN',
#  'MITSUBISHI',
#  'CHRYSLER',
#  'LAND ROVER',
#  'FIAT',
#  'ACURA',
#  'MASERATI',
#  'ROLLS-ROYCE',
#  'ASTON MARTIN',
#  'BENTLEY',
#  'LAMBORGHINI',
#  'ALFA ROMEO',
#  'GENESIS',
#  'SCION',
#  'SMART',
#  'BUGATTI',
#  'SRT']

# %%
make_6_list = list(np.array(make_vehicles).reshape(-1, 6))

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[0])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[1])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[2])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[3])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[4])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[5])

# %%
ax = sns.boxplot(x = 'Make', y = target, data = df, order=make_6_list[6])

# %% [markdown]
# ##### Notes
# - Lamborghini has high CO2 emissions
# - Land Rover, GMC, and RAM have pretty high CO2 emissions as well
# - SMART, FIAT have low CO2 emissions
#
# Check the box plot for other interesting relationships

# %% [markdown]
# #### Comparing CO2 emissions with the Vehicle Class

# %%
vehicle_class_list = list(np.array(df['Vehicle Class'].value_counts().sort_values(ascending = False).keys()).reshape(-1, 4))
vehicle_class_list
# Out:
# [array(['SUV - SMALL', 'MID-SIZE', 'COMPACT', 'SUV - STANDARD'],
#        dtype=object),
#  array(['FULL-SIZE', 'SUBCOMPACT', 'PICKUP TRUCK - STANDARD', 'TWO-SEATER'],
#        dtype=object),
#  array(['MINICOMPACT', 'STATION WAGON - SMALL', 'PICKUP TRUCK - SMALL',
#         'MINIVAN'], dtype=object),
#  array(['SPECIAL PURPOSE VEHICLE', 'VAN - PASSENGER',
#         'STATION WAGON - MID-SIZE', 'VAN - CARGO'], dtype=object)]

# %%
ax = sns.boxplot(x = 'Vehicle Class', y = target, data = df, order=vehicle_class_list[0])

# %%
ax = sns.boxplot(x = 'Vehicle Class', y = target, data = df, order=vehicle_class_list[1])

# %%
ax = sns.boxplot(x = 'Vehicle Class', y = target, data = df, order=vehicle_class_list[2])

# %%
ax = sns.boxplot(x = 'Vehicle Class', y = target, data = df, order=vehicle_class_list[3])

# %% [markdown]
# ##### Notes
#
# - Passenger Vans generally have high CO2 emissions
# - Station Wagon generally have less CO2 emissions

# %% [markdown]
# #### Comparing CO2 emissions with vehicle transmission

# %%
transmission_list = list(np.array(df['Transmission'].value_counts().sort_values(ascending = False).keys()).reshape(-1, 9))
transmission_list
# Out:
# [array(['AS6', 'AS8', 'M6', 'A6', 'A8', 'AM7', 'A9', 'AS7', 'AV'],
#        dtype=object),
#  array(['M5', 'AS10', 'AM6', 'AV7', 'AV6', 'M7', 'A5', 'AS9', 'A4'],
#        dtype=object),
#  array(['AM8', 'A7', 'AV8', 'A10', 'AS5', 'AV10', 'AM5', 'AM9', 'AS4'],
#        dtype=object)]

# %%
ax = sns.boxplot(x = 'Transmission', y = target, data = df, order=transmission_list[0])

# %%
ax = sns.boxplot(x = 'Transmission', y = target, data = df, order=transmission_list[1])

# %%
ax = sns.boxplot(x = 'Transmission', y = target, data = df, order=transmission_list[2])

# %% [markdown]
# ##### Notes
#
# - A4 transmission vehicles generally have CO2 emissions
# - AV and AM6 tranmission vehicles generally have less CO2 emissions

# %% [markdown]
# #### Comparing CO2 emissions with Fuel type of vehicle

# %% [markdown]
# - X -> Regular Gasoline
# - Z -> Premium Gasoline
# - E -> Ethanol
# - D -> Diesel
# - N -> Natural Gas

# %%
fuel_type_list = list(np.array(df['Fuel Type'].value_counts().sort_values(ascending = False).keys()))
fuel_type_list
# Out:
# ['X', 'Z', 'E', 'D', 'N']

# %%
ax = sns.boxplot(x = 'Fuel Type', y = target, data = df, order=fuel_type_list)

# %% [markdown]
# ##### Notes
#
# - Regular gasoline has less CO2 emissions generally
# - Premium gasoline emit more CO2 generally

# %% [markdown]
# #### Comparing CO2 emissions with engine size

# %%
sns.regplot(data=df, x="Engine Size(L)", y=target)
# Out:
# <AxesSubplot:xlabel='Engine Size(L)', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# ##### Note
#
# - There is an increasing trend of CO2 emissions as engine size increases

# %% [markdown]
# #### Comparing CO2 emissions with number of cylinders in vehicles

# %%
df['Cylinders'].value_counts()
# Out:
# 4     3220
# 6     2446
# 8     1402
# 12     151
# 3       95
# 10      42
# 5       26
# 16       3
# Name: Cylinders, dtype: int64

# %%
df['Cylinders'] = df['Cylinders'].astype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   object
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
# ...

# %%
cylinders_list = list(np.array(df['Cylinders'].value_counts().sort_values(ascending = False).keys()).reshape(-1, 4))
cylinders_list
# Out:
# [array([ 4,  6,  8, 12]), array([ 3, 10,  5, 16])]

# %%
ax = sns.boxplot(x = 'Cylinders', y = target, data = df, order=cylinders_list[0])

# %%
ax = sns.boxplot(x = 'Cylinders', y = target, data = df, order=cylinders_list[1])

# %% [markdown]
# ##### Note
#
# - Vehicles with 12 cylinders emit more CO2 generally
# - Vehicles with less cylinders emit less CO2 generally

# %% [markdown]
# #### Comparing CO2 emissions with fuel consumption in city

# %%
sns.regplot(data=df, x="Fuel Consumption City (L/100 km)", y=target)
# Out:
# <AxesSubplot:xlabel='Fuel Consumption City (L/100 km)', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# ##### Note
#
# - An increasing trend can be seen in CO2 emissions as fuel consumption in cities increase

# %% [markdown]
# #### Comparing CO2 emissions with fuel consumption in highway

# %%
sns.regplot(data=df, x="Fuel Consumption Hwy (L/100 km)", y=target)
# Out:
# <AxesSubplot:xlabel='Fuel Consumption Hwy (L/100 km)', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# ##### Note
#
# - An increasing trend can be seen in CO2 emissions as fuel consumption in highways increase

# %% [markdown]
# #### Comparing CO2 emissions with fuel consumption in mpg (combined)

# %%
sns.regplot(data=df, x="Fuel Consumption Comb (mpg)", y=target)
# Out:
# <AxesSubplot:xlabel='Fuel Consumption Comb (mpg)', ylabel='CO2 Emissions(g/km)'>

# %% [markdown]
# ##### Note
#
# - A decreasing trend can be seen in CO2 emissions as miles per gallon in vehicles increase
